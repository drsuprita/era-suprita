# %%
import pandas as pd
import numpy as np
data=pd.read_csv(r"C:\\Users\\Sanketreddy\\AppData\\Local\\Packages\\5319275A.WhatsAppDesktop_cv1g1gvanyjgm\\LocalState\\sessions\\C4FC6A3FA7AEB8D1004ACD58B7C5B1193F260465\\transfers\\2026-07\\raw_students.csv")
data
# Out:
#    StudentID          Name     Age  Gender  Score                Email
# 0          1      John doe      20    male   85.0     john@example.com
# 1          2   Jane Smith       19  Female   90.0  janesmith@email.com
# 2          3   Bob Johnson     NaN    Male   78.0       bobj@email.com
# 3          4   Alice Brown      21  Female    NaN      alice@email.com
# 4          5     Chris Lee  twenty    Male   88.0          chris@email
# 5          6      John Doe      20    Male   85.0     john@example.com
# 6          7           NaN      22  Female   92.0      sarah@email.com
# 7          8  Michael King      23    Male   75.0    michael@email.com

# %%
data["Age"]= pd.to_numeric(data["Age"], errors="coerce")
data.dtypes
# Out:
# StudentID      int64
# Name             str
# Age          float64
# Gender           str
# Score        float64
# Email            str
# dtype: object

# %%
data.isnull().sum()
# Out:
# StudentID    0
# Name         1
# Age          2
# Gender       0
# Score        1
# Email        0
# dtype: int64

# %%
data["Age"].fillna(data["Age"].mean())
# Out:
# 0    20.000000
# 1    19.000000
# 2    20.833333
# 3    21.000000
# 4    20.833333
# 5    20.000000
# 6    22.000000
# 7    23.000000
# Name: Age, dtype: float64

# %%
data["Score"].fillna(data["Score"].median())
# Out:
# 0    85.0
# 1    90.0
# 2    78.0
# 3    85.0
# 4    88.0
# 5    85.0
# 6    92.0
# 7    75.0
# Name: Score, dtype: float64

# %%
data["Name"]=data["Name"].fillna("Unknown")
data
# Out:
#    StudentID          Name   Age  Gender  Score                Email
# 0          1      John doe  20.0    male   85.0     john@example.com
# 1          2   Jane Smith   19.0  Female   90.0  janesmith@email.com
# 2          3   Bob Johnson   NaN    Male   78.0       bobj@email.com
# 3          4   Alice Brown  21.0  Female    NaN      alice@email.com
# 4          5     Chris Lee   NaN    Male   88.0          chris@email
# 5          6      John Doe  20.0    Male   85.0     john@example.com
# 6          7       Unknown  22.0  Female   92.0      sarah@email.com
# 7          8  Michael King  23.0    Male   75.0    michael@email.com

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
data=pd.read_csv(r"C:\\Users\\Sanketreddy\\AppData\\Local\\Packages\\5319275A.WhatsAppDesktop_cv1g1gvanyjgm\\LocalState\\sessions\\C4FC6A3FA7AEB8D1004ACD58B7C5B1193F260465\\transfers\\2026-07\\sample2.csv")
data
# Out:
#     Unnamed: 0  Age  Salary  Experience  Monthly_Sales
# 0            0   22   30000           1            200
# 1            1   25   32000           2            220
# 2            2   28   35000           3            250
# 3            3   30   40000           5            300
# 4            4   24   38000           4            280
# 5            5   27   36000           3            260
# 6            6   29   37000           4            270
# 7            7   31   39000           6            290
# 8            8   26   41000           5            310
# 9            9   23   42000           2            320
# 10          10   32   45000           7            330
# 11          11   33   47000           8            350
# 12          12   29   44000           6            340
# 13          13   28   43000           5            360
# 14          14   27   46000           4            370
# 15          15   26   48000           3            380
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0         Age         Salary  Experience  Monthly_Sales
# count   25.000000   25.000000      25.000000   25.000000      25.000000
# mean    12.000000   32.680000   53840.000000    6.000000     445.600000
# std      7.359801   21.332135   52469.578488    8.266398     551.815791
# min      0.000000   19.000000   28000.000000    0.000000     180.000000
# 25%      6.000000   24.000000   33000.000000    2.000000     230.000000
# 50%     12.000000   27.000000   40000.000000    4.000000     300.000000
# 75%     18.000000   30.000000   46000.000000    6.000000     360.000000
# max     24.000000  105.000000  250000.000000   35.000000    2500.000000

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.3 MB 2.6 MB/s eta 0:00:03
#    ------------ --------------------------- 2.6/8.3 MB 4.6 MB/s eta 0:00:02
#    ------------------------------ --------- 6.3/8.3 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.3 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 7.6 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------------------------ --- 2.1/2.3 MB 17.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 4.1 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/6 [pyparsing]
#    ---------------------------------------- 0/6 [pyparsing]
#    ---------------------------------------- 0/6 [pyparsing]
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/37.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/37.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/37.1 MB ? eta -:--:--
#     --------------------------------------- 0.8/37.1 MB 2.2 MB/s eta 0:00:17
#    -- ------------------------------------- 2.1/37.1 MB 3.9 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.5/37.1 MB 7.1 MB/s eta 0:00:05
#    --------- ------------------------------ 8.9/37.1 MB 8.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 15.2/37.1 MB 11.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.2/37.1 MB 11.2 MB/s eta 0:00:02
#    --------------------- ------------------ 19.7/37.1 MB 10.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.2/37.1 MB 10.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 26.7/37.1 MB 11.8 MB/s eta 0:00:01
# ...

# %%
pip install zscore
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/633.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/633.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/633.2 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/633.2 kB ? eta -:--:--
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as z_score
import pandas as pd

# %%
data=pd.read_csv(r"C:\\Users\\Sanketreddy\\AppData\\Local\\Packages\\5319275A.WhatsAppDesktop_cv1g1gvanyjgm\\LocalState\\sessions\\C4FC6A3FA7AEB8D1004ACD58B7C5B1193F260465\\transfers\\2026-07\\sample2.csv")
data
# Out:
#     Unnamed: 0  Age  Salary  Experience  Monthly_Sales
# 0            0   22   30000           1            200
# 1            1   25   32000           2            220
# 2            2   28   35000           3            250
# 3            3   30   40000           5            300
# 4            4   24   38000           4            280
# 5            5   27   36000           3            260
# 6            6   29   37000           4            270
# 7            7   31   39000           6            290
# 8            8   26   41000           5            310
# 9            9   23   42000           2            320
# 10          10   32   45000           7            330
# 11          11   33   47000           8            350
# 12          12   29   44000           6            340
# 13          13   28   43000           5            360
# 14          14   27   46000           4            370
# 15          15   26   48000           3            380
# ...

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)
data
# Out:
#     Age  Salary  Experience  Monthly_Sales
# 0    22   30000           1            200
# 1    25   32000           2            220
# 2    28   35000           3            250
# 3    30   40000           5            300
# 4    24   38000           4            280
# 5    27   36000           3            260
# 6    29   37000           4            270
# 7    31   39000           6            290
# 8    26   41000           5            310
# 9    23   42000           2            320
# 10   32   45000           7            330
# 11   33   47000           8            350
# 12   29   44000           6            340
# 13   28   43000           5            360
# 14   27   46000           4            370
# 15   26   48000           3            380
# 16   30   50000           5            390
# 17   31   52000           6            400
# 18   24   31000           2            210
# 19   25   33000           1            230
# 20  100  200000          30           2000
# ...

# %%
fig, axs = plt.subplots(1, 4, figsize=(16, 6))
axs[0].boxplot(data.Age)
axs[1].boxplot(data.Salary)
axs[2].boxplot(data.Experience)
axs[3].boxplot(data.Monthly_Sales)
plt.show()

# %%
Q1=data.quantile(0.25)
Q3=data.quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# Age                  6.0
# Salary           13000.0
# Experience           4.0
# Monthly_Sales      130.0
# dtype: float64

# %%
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR
upper_limit,lower_limit
# Out:
# (Age                 39.0
#  Salary           65500.0
#  Experience          12.0
#  Monthly_Sales      555.0
#  dtype: float64,
#  Age                 15.0
#  Salary           13500.0
#  Experience          -4.0
#  Monthly_Sales       35.0
#  dtype: float64)

# %%
outliers = data[(data < lower_limit) | (data > upper_limit)].any(axis=1)
data[outliers]
# Out:
#     Age  Salary  Experience  Monthly_Sales
# 20  100  200000          30           2000
# 21  105  250000          35           2500

# %%
cleaned_data = data[~outliers]
cleaned_data
cleaned_data.head()
# Out:
#    Age  Salary  Experience  Monthly_Sales
# 0   22   30000           1            200
# 1   25   32000           2            220
# 2   28   35000           3            250
# 3   30   40000           5            300
# 4   24   38000           4            280

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(data=cleaned_data)
plt.show()

# %%
fig, axs = plt.subplots(1, 4, figsize=(16, 6))
axs[0].boxplot(cleaned_data.Age)
axs[1].boxplot(cleaned_data.Salary)
axs[2].boxplot(cleaned_data.Experience)
axs[3].boxplot(cleaned_data.Monthly_Sales)
plt.show()

# %%
pip install z_score
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement z_score (from versions: none)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for z_score

# %%
from scipy.stats import zscore
z_score=np.absolute(zscore(data))
z_score_mask=(z_score>3).any(axis=1)
data[z_score_mask]
# Out:
#     Age  Salary  Experience  Monthly_Sales
# 20  100  200000          30           2000
# 21  105  250000          35           2500
