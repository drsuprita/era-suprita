# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler

data = {
    "Age": [22, 25, 30, 35, 40, 28, 50, 45, 32, 26],
    "Salary": [30000, 35000, 60000, 80000, 120000, 52000, 150000, 110000, 75000, 40000]
}

df = pd.DataFrame(data)

standard_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()

df_standardized = pd.DataFrame(standard_scaler.fit_transform(df), columns=df.columns)
df_normalized = pd.DataFrame(minmax_scaler.fit_transform(df), columns=df.columns)

plt.figure(figsize=(15,4))

plt.subplot(1,3,1)
plt.hist(df["Salary"], bins=5)
plt.title("Original Salary")

plt.subplot(1,3,2)
plt.hist(df_standardized["Salary"], bins=5)
plt.title("Standardized Salary")

plt.subplot(1,3,3)
plt.hist(df_normalized["Salary"], bins=5)
plt.title("Normalized Salary")

plt.tight_layout()
plt.show()
